# %%
import mne
import numpy as np

# %%
path = "/home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-117/sub-117-001-eve.fif"

# %%
events = mne.read_events(path)

# %%
events[7:]
# Out:
# array([[ 5707,     0,   252],
#        [ 6040,     0,    20],
#        [ 7040,     0,    30],
#        [ 7645,     0,    80],
#        [ 7665,     0,    60],
#        [ 8065,     0,    20],
#        [ 8710,     0,    30],
#        [ 9290,     0,    80],
#        [ 9310,     0,    60],
#        [ 9615,     0,    20],
#        [10340,     0,    30],
#        [11120,     0,    80],
#        [11136,     0,    60],
#        [11711,     0,    20],
#        [12826,     0,    30],
#        [13506,     0,    80],
#        [13526,     0,    60],
#        [13856,     0,    20],
#        [14816,     0,    30],
#        [15652,     0,    80],
#        [15672,     0,    60],
#        [16232,     0,    20],
#        [17242,     0,    30],
#        [18103,     0,    80],
#        [18123,     0,    60],
#        [18713,     0,    20],
#        [19894,     0,    30],
#        [20999,     0,    80],
#        [21019,     0,    60],
#        [21579,     0,    20],
#        [22664,     0,    30],
# ...

# %%
mne.write_events(path, events[7:])
